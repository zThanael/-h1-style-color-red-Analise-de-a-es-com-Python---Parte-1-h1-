# %% [markdown]
# <h1 style='color:red'> Analise de ações com Python  <i style='color:black'>- Parte 1</i></h1>

# %% [markdown]
# <p> Ao decorrer deste Notebook, vou mostrar o processo que eu utilizo para realizar uma filtragem inicial nas ações, para visualizar as ações cujo indicadores estão melhores na minha visão

# %% [markdown]
# <h2> Separaremos este notebook em Etapas </h2>

# %% [markdown]
# <li> Importação das Bibliotecas </li>
# <li> Obtenção dos dados das ações </li>
# <li> Tratamento dos dados </li>
# <li> Visualização dos dados </li>

# %% [markdown]
# <h2 style='color:red'> Importação das Bibliotecas </h2>

# %%
import requests
from bs4 import BeautifulSoup
import json
import time
import datetime 
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# <h2 style='color:red'> Obtenção dos dados das ações </h2>

# %% [markdown]
# <p> Para realizar a obtenção dos dados vamos utilizar de uma tecnica chamada de WebScrapping para realizar a raspagem de dados do site <b><a href='https://statusinvest.com.br/'> Status Invest </a></b> </p>

# %% [markdown]
# <h3> Criar as funções que serão utilizadas neste processo </h3>

# %%
# Realizar o GET para obter o HTML do site
def request(url):
    url_padrao = url
    
    response = requests.get(url)
    
    if response.status_code == 200:
        #print('Request Sucess!')
        html = response.content
        return BeautifulSoup(html,'html.parser')
    elif response.status_code == 429:
        print('HTTP 429 - Limite de requisições por tempo \n Esperando 1 minuto')
        time.sleep(60)
    elif response.status_code >= 500:
        print(f'HTTP {response.status_code} \n{response.content}')
    else:
        print('Verifique se o nome está correto. ')

# %%
# Obter a tag do HTML que obtem o nome da ação
def get_name(soup,acao):
    cabecalho = soup.find('h1',{'class':'lh-4'}).get_text().split(' - ')

    acao['nome'] = cabecalho[1]
    acao['acao'] = cabecalho[0]
    
    return acao

# %%
# Obter a tag do HTML que obtem o setor da ação
def get_setor(soup, acao):
    info_setor = soup.find('div',{'class':'card bg-main-gd-h white-text rounded ov-hidden pt-0 pb-0'})
    
    for info in info_setor:
        if info == '\n': continue 

        nomes =  info.find_all('span',{'class':'sub-value'})
        valores = info.find_all('strong',{'class':'value'})

    nomes = [nome.get_text() for nome in nomes]
    valores =[valor.get_text() for valor in valores]

    for i in range(len(nomes)):
        acao[nomes[i]] = valores[i]
    
    return acao

# %%
# Obter a tag do HTML que armazena os indicadores e informações das ações
def get_indicador(indicador,acao):
    
    for div in indicador:
        if div == '\n': continue 
            
        if div.find('h3',{'class':'title'}).get_text() == '':
            titulo = div.find_all('h3',{'class':'title'})[1].get_text()
        else:
            titulo = div.find('h3',{'class':'title'})
            if len(titulo) == 5:
                titulo = titulo.find('span',{'class':'d-inline-block mr-2'}).get_text()
            else: 
                titulo = div.find('h3',{'class':'title'}).get_text()

            
        valor = div.find('strong',{'class':'value'}).get_text().replace(',','.')
        acao[titulo] = valor
        
    return acao

# %% [markdown]
# <h3> Realizar o Web Scraping </h3>

# %% [markdown]
# <p> Primeiro precisamos obter o nome das ações onde vamos realizar o Scraping, para isso basta abrir a <b> <a href='https://statusinvest.com.br/acoes/busca-avancada'> Busca Avançada de Ações </a> </b> e filtrar por um setor e baixar seu arquivo .csv e renomear ele como empresas.csv.

# %% [markdown]
# <b> <i> Obs: Poderiamos analisar diretamento o arquivo csv e não precisar utilizar o processo de Web Scraping , porém percebi que no arquivo CSV faltam alguns indicadores como <u> Liquidez Corrente </u>, <u> Dívida Líquida / EBITDA </u> e outros </b> </i>

# %%
empresas = pd.read_csv('empresas.csv',sep=';')['TICKER']

# %%
empresas.head(2)
# Out:
# 0    CSAN3
# 1    DMMO3
# Name: TICKER, dtype: object

# %%
lista_acoes = []
before = datetime.datetime.now()

# percorrer pela ação obtendo seus indicadores
for empresa in empresas:
    url = 'https://statusinvest.com.br/'

    link = f'{url}acoes/{empresa}'
    soup = request(link)
    
    # Obter as informações das acoes
    acao = {}
    
    #Obter o nome e setor
    acao = get_name(soup,acao)
    acao = get_setor(soup,acao)
    
    
    # Obter o Header
    header = soup.find('div',{'class':'top-info has-special d-flex justify-between flex-wrap'})
    acao = get_indicador(header,acao)
    
    # Obter os números
    numeros = soup.find('div',{'class':'top-info info-3 sm d-flex justify-between mb-3'})
    acao = get_indicador(numeros,acao)
    
    # Obter os indicadores
    indicadores = soup.find_all('div',{'d-flex flex-wrap align-items-center justify-start'})[:5]
    
    for indicador in indicadores:
        acao = get_indicador(indicador,acao)
    
    #LINK
    acao['link'] = link
    
    lista_acoes.append(acao)
    
after = datetime.datetime.now()
print(f'Tempo de execução {after - before}')
# Out:
# Tempo de execução 0:00:15.213893

# %% [markdown]
# <h3> Criar o DataFrame com as informações </h3>

# %% [markdown]
# <p> Agora basta criarmos o DataFrame inicial no qual iremos trabalhar </p>

# %%
df_raw = pd.DataFrame(lista_acoes)
df = df_raw.copy()

# %% [markdown]
# <h2 style='color:red'> Tratamento dos dados </h2>

# %% [markdown]
# <p> Visualização do DataFrame Inicial </p>

# %%
df.head(2)
# Out:
#             nome   acao                 Setor de Atuação  \
# 0          COSAN  CSAN3  Petróleo. Gás e Biocombustíveis
# 1  DOMMO ENERGIA  DMMO3  Petróleo. Gás e Biocombustíveis
#
#                Subsetor de Atuação                Segmento de Atuação  \
# 0  Petróleo. Gás e Biocombustíveis  Exploração. Refino e Distribuição
# 1  Petróleo. Gás e Biocombustíveis  Exploração. Refino e Distribuição
#
#   Valor atual Min. 52 semanas Máx. 52 semanas Dividend Yield  \
# 0       17.25           16.77           24.58           4.65
# 1        1.74            0.44            1.86              -
#
#   Valorização (12m) Patrimônio líquido          Ativos Ativo circulante  \
# 0           -25.07%     15.647.431.000  96.006.859.000   24.194.616.000
# 1           125.97%       -503.962.000     343.940.000      201.458.000
#
#      Dívida bruta Disponibilidade  Dívida líquida Valor de mercado  \
# 0  43.349.331.000  12.083.132.000  31.266.199.000   32.327.723.577
# 1          82.000      77.487.000     -77.405.000      886.852.020
#
#    Valor de firma Nº total de papéis Segmento de listagem Free Float     \
# 0  63.593.922.577      1.874.070.932         Novo Mercado     62.49%
# 1     809.447.020        509.685.069                          43.79%
#
#      D.Y     P/L PEG Ratio   P/VP EV/EBITDA EV/EBIT P/EBITDA P/EBIT    VPA  \
# 0  4.65%    6.56      0.07   2.07      5.40    7.06     2.74   3.59   8.35
# 1     -%  -39.86      0.38  -1.76         -   27.61        -  30.25  -0.99
#
#   P/Ativo    LPA  P/SR P/Cap. Giro P/Ativo Circ. Liq. Dív. líquida/PL  \
# 0    0.34   2.63  1.04        2.84              -0.45            2.00
# 1    2.58  -0.04  3.01        8.63              -6.22               -
#
#   Dív. líquida/EBITDA Dív. líquida/EBIT PL/Ativos Passivos/Ativos  \
# 0                2.65              3.47      0.16            0.68
# 1                   -             -2.64     -1.47            2.47
#
#   Liq. corrente M. Bruta M. EBITDA M. EBIT M. Líquida     ROE     ROA    ROIC  \
# 0          1.89   23.73%    37.88%  28.95%     15.84%  31.49%   5.13%  11.19%
# 1          2.04   65.75%        -%   9.94%     -7.55%  -4.42%  -6.47%  -5.82%
#
#   Giro ativos CAGR Receitas 5 anos CAGR Lucros 5 anos  \
# 0        0.32               26.99%             36.60%
# 1        0.86               -1.34%                 -%
#
#                                       link
# 0  https://statusinvest.com.br/acoes/CSAN3
# 1  https://statusinvest.com.br/acoes/DMMO3

# %% [markdown]
# <h3> Filtrar as colunas </h3>

# %% [markdown]
# <p> Verificar as colunas e tipos de dados </p>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 53 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   nome                  15 non-null     object
#  1   acao                  15 non-null     object
#  2   Setor de Atuação      15 non-null     object
#  3   Subsetor de Atuação   15 non-null     object
#  4   Segmento de Atuação   15 non-null     object
#  5   Valor atual           15 non-null     object
#  6   Min. 52 semanas       15 non-null     object
#  7   Máx. 52 semanas       15 non-null     object
#  8   Dividend Yield        15 non-null     object
#  9   Valorização (12m)     15 non-null     object
#  10  Patrimônio líquido    15 non-null     object
#  11  Ativos                15 non-null     object
#  12  Ativo circulante      15 non-null     object
#  13  Dívida bruta          15 non-null     object
#  14  Disponibilidade       15 non-null     object
#  15  Dívida líquida        15 non-null     object
#  16  Valor de mercado      15 non-null     object
#  17  Valor de firma        15 non-null     object
#  18  Nº total de papéis    15 non-null     object
#  19  Segmento de listagem  15 non-null     object
#  20  Free Float            15 non-null     object
#  21                        15 non-null     object
#  22  D.Y                   15 non-null     object
#  23  P/L                   15 non-null     object
#  24  PEG Ratio             15 non-null     object
#  25  P/VP                  15 non-null     object
#  26  EV/EBITDA             15 non-null     object
#  27  EV/EBIT               15 non-null     object
#  28  P/EBITDA              15 non-null     object
#  29  P/EBIT                15 non-null     object
#  30  VPA                   15 non-null     object
#  31  P/Ativo               15 non-null     object
#  32  LPA                   15 non-null     object
#  33  P/SR                  15 non-null     object
#  34  P/Cap. Giro           15 non-null     object
#  35  P/Ativo Circ. Liq.    15 non-null     object
#  36  Dív. líquida/PL       15 non-null     object
#  37  Dív. líquida/EBITDA   15 non-null     object
#  38  Dív. líquida/EBIT     15 non-null     object
#  39  PL/Ativos             15 non-null     object
#  40  Passivos/Ativos       15 non-null     object
#  41  Liq. corrente         15 non-null     object
#  42  M. Bruta              15 non-null     object
#  43  M. EBITDA             15 non-null     object
#  44  M. EBIT               15 non-null     object
#  45  M. Líquida            15 non-null     object
#  46  ROE                   15 non-null     object
#  47  ROA                   15 non-null     object
#  48  ROIC                  15 non-null     object
#  49  Giro ativos           15 non-null     object
#  50  CAGR Receitas 5 anos  15 non-null     object
#  51  CAGR Lucros 5 anos    15 non-null     object
#  52  link                  15 non-null     object
# dtypes: object(53)
# memory usage: 6.3+ KB

# %% [markdown]
# <p> Com base nessas informações percebemos que os tipos de dados estão errados e existem diversas colunas que não seram utilizadas neste momento </p>

# %% [markdown]
# <p> Portanto vamos realizar uma filtragem de colunas inicialmente deixando somente as colunas que irie utilizar em minhas analises futuramente </p>

# %%
df.drop(columns=['nome','Segmento de Atuação','\xa0'],inplace = True,errors='ignore')
df = df[['acao','Subsetor de Atuação','Valor atual','Dividend Yield','Valorização (12m)','P/L','P/VP','EV/EBITDA','PEG Ratio','CAGR Receitas 5 anos','CAGR Lucros 5 anos','M. EBITDA','ROE','ROIC','Dívida líquida','Dív. líquida/PL','Dív. líquida/EBITDA','Liq. corrente','link']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   acao                  15 non-null     object
#  1   Subsetor de Atuação   15 non-null     object
#  2   Valor atual           15 non-null     object
#  3   Dividend Yield        15 non-null     object
#  4   Valorização (12m)     15 non-null     object
#  5   P/L                   15 non-null     object
#  6   P/VP                  15 non-null     object
#  7   EV/EBITDA             15 non-null     object
#  8   PEG Ratio             15 non-null     object
#  9   CAGR Receitas 5 anos  15 non-null     object
#  10  CAGR Lucros 5 anos    15 non-null     object
#  11  M. EBITDA             15 non-null     object
#  12  ROE                   15 non-null     object
#  13  ROIC                  15 non-null     object
#  14  Dívida líquida        15 non-null     object
#  15  Dív. líquida/PL       15 non-null     object
#  16  Dív. líquida/EBITDA   15 non-null     object
#  17  Liq. corrente         15 non-null     object
#  18  link                  15 non-null     object
# dtypes: object(19)
# memory usage: 2.4+ KB

# %% [markdown]
# <p> Agora já temos menos colunas, porém ainda precisamos ajustar seu tipo de dados para os tipos adequados de INT e FLOAT </p>

# %% [markdown]
# <h3> Ajustar os tipos de dados </h3>

# %%
df = df.replace(['-','-%','--%'],'0')

# %% [markdown]
# <h4> Ajustar os registros de % </h4>

# %%
colunas_porcentagem = [coluna for coluna in df.columns if '%' in df[coluna].astype(str).str.slice(-1).unique()]

# %%
# Tratativa para as colunas de %
for coluna in colunas_porcentagem:
    df[coluna] = df[coluna].str.replace('%','')
    df[coluna] = df[coluna].apply(lambda x: x.replace('.','') if x[:-3].find('.') != -1 else x)
    df[coluna] = df[coluna].astype(float)
    
df.columns  = [coluna + ' %' if coluna in colunas_porcentagem else coluna for coluna in df.columns]

# %% [markdown]
# <h4> Ajustar os registros cujo valor seja FLOAT </h4>

# %%
colunas_float = ['Valor atual','Dividend Yield','P/L','P/VP','EV/EBITDA','PEG Ratio','Dívida líquida','Dív. líquida/PL','Dív. líquida/EBITDA','Liq. corrente']

# %%
for coluna in colunas_float:
    df[coluna] = df[coluna].apply(lambda valor : valor[:-3].replace('.','') + valor[-3:])
    if coluna == 'Dívida líquida':
        df[coluna] = df[coluna].astype(np.int64)
    df[coluna] = df[coluna].astype(float)

# %% [markdown]
# <p> Agora já temos o DataFrame com os dados devidamente corretos </p>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   acao                    15 non-null     object
#  1   Subsetor de Atuação     15 non-null     object
#  2   Valor atual             15 non-null     float64
#  3   Dividend Yield          15 non-null     float64
#  4   Valorização (12m) %     15 non-null     float64
#  5   P/L                     15 non-null     float64
#  6   P/VP                    15 non-null     float64
#  7   EV/EBITDA               15 non-null     float64
#  8   PEG Ratio               15 non-null     float64
#  9   CAGR Receitas 5 anos %  15 non-null     float64
#  10  CAGR Lucros 5 anos %    15 non-null     float64
#  11  M. EBITDA %             15 non-null     float64
#  12  ROE %                   15 non-null     float64
#  13  ROIC %                  15 non-null     float64
#  14  Dívida líquida          15 non-null     float64
#  15  Dív. líquida/PL         15 non-null     float64
#  16  Dív. líquida/EBITDA     15 non-null     float64
#  17  Liq. corrente           15 non-null     float64
#  18  link                    15 non-null     object
# dtypes: float64(16), object(3)
# memory usage: 2.4+ KB

# %% [markdown]
# <p> Observe que agora temos um conjunto de dados mais organizados, facilitanto o entendimento do mesmo

# %%
df.head(2)
# Out:
#     acao              Subsetor de Atuação  Valor atual  Dividend Yield  \
# 0  CSAN3  Petróleo. Gás e Biocombustíveis        17.25            4.65
# 1  DMMO3  Petróleo. Gás e Biocombustíveis         1.74            0.00
#
#    Valorização (12m) %    P/L  P/VP  EV/EBITDA  PEG Ratio  \
# 0               -25.07   6.56  2.07        5.4       0.07
# 1               125.97 -39.86 -1.76        0.0       0.38
#
#    CAGR Receitas 5 anos %  CAGR Lucros 5 anos %  M. EBITDA %  ROE %  ROIC %  \
# 0                   26.99                  36.6        37.88  31.49   11.19
# 1                   -1.34                   0.0         0.00  -4.42   -5.82
#
#    Dívida líquida  Dív. líquida/PL  Dív. líquida/EBITDA  Liq. corrente  \
# 0    3.126620e+10              2.0                 2.65           1.89
# 1   -7.740500e+07              0.0                 0.00           2.04
#
#                                       link
# 0  https://statusinvest.com.br/acoes/CSAN3
# 1  https://statusinvest.com.br/acoes/DMMO3

# %% [markdown]
# # Visualização dos dados

# %% [markdown]
# <p> Para visualização, vou ajustar alguns pontos no proprio DataFrame para facilitar a visualização dos dados, para isso vou usar algumas cores para sinalizar seus indicadores, por exemplo:<br>
#     <b style='color:green'>Verde: Bom</b> <br>
#     <b style='color:red'>Vermelho: Ruim</b> <br>

# %% [markdown]
# <p> <b> <i> Lembrando que esse modo de analisar ações é o modo do qual eu utilizo, o que não significa que é o melhor ou que esteja 100% correto, mas sim o que eu particularmente gosto de usar para analisar as ações das quais pretendo comprar, sendo esta uma primeira filtragem das ações com base nos indicadores, após isso realizo uma analise mais aprofundada individualmente sobre as ações que escolher com base nesta filtragem.</i></b></p>

# %%
# Criação de funções para setar as alterações dependendo da cor 

def good_value():
    return 'background-color: #2E924C; font-weight: bold'

def medium_value():
    return 'background-color: #FFFFE5; color:black; opacity: 95%'

def bad_value():
    return 'background-color: red; font-weight: bold'

# %%
# Ordenar pelo setor
df = df.sort_values(by='Subsetor de Atuação')

# %%
# Remover uma ação cujo indicador estava muito alterao | com Margem de 271124.00%
df = df.drop(5)

# %%
df_view = (
df.style
            # Ajustar as casas decimais
            .format('{:.2f}', na_rep='MISS',subset=[coluna  for coluna in df.columns if coluna not in ('acao','Subsetor de Atuação','link')])
            .format('{:.2f}%', na_rep='MISS',subset=['Valorização (12m) %','M. EBITDA %','ROE %','ROIC %','CAGR Receitas 5 anos %','CAGR Lucros 5 anos %'])
            # Indicadores de Preço
            .applymap(lambda v: good_value() if (v > 0) and (v < 20)  else medium_value(), subset=['P/L'])
            .applymap(lambda v: good_value() if (v > 2)  else (medium_value() if v >= 0 and v <= 2 else bad_value()), subset=['P/VP'])
             #Indicadores de Crescimento
            .applymap(lambda v: good_value() if (v < 1) and (v > 0)  else (medium_value() if v >= 2 and v <= 2 else bad_value()),subset=['PEG Ratio'])
            # Rentabilidade
            .background_gradient(cmap='YlGn',subset=['M. EBITDA %','ROE %','ROIC %'])
            # Indicadores de Individamentos
            .applymap(lambda v: good_value() if (v < 1)  else (medium_value() if v >= 1 and v<= 3 else bad_value()), 
                      subset=['Dív. líquida/EBITDA'])
)

# %% [markdown]
# <h2> Visualizando as ações e seus indicadores </h2>

# %% [markdown]
# <p> Perceba que agora fica muito mais fácil visualizar as ações e seus indicadores, sabendo que por exemplos as ações em vermelho possuem indicadores não tão atrativos com base no tipo de ação que eu busco. Enquanto que as ações verdes estão com indicadores mais aceitaveis com base nos critérios que eu utilizo</p>

# %%
df_view
# Out:
# <style type="text/css">
# #T_538a2_row0_col5, #T_538a2_row0_col6, #T_538a2_row0_col8, #T_538a2_row1_col8, #T_538a2_row1_col16, #T_538a2_row2_col5, #T_538a2_row2_col8, #T_538a2_row2_col16, #T_538a2_row3_col8, #T_538a2_row3_col16, #T_538a2_row4_col8, #T_538a2_row4_col16, #T_538a2_row5_col5, #T_538a2_row5_col8, #T_538a2_row5_col16, #T_538a2_row6_col5, #T_538a2_row6_col8, #T_538a2_row6_col16, #T_538a2_row7_col5, #T_538a2_row7_col6, #T_538a2_row7_col8, #T_538a2_row7_col16, #T_538a2_row8_col5, #T_538a2_row8_col8, #T_538a2_row9_col5, #T_538a2_row9_col6, #T_538a2_row9_col8, #T_538a2_row9_col16, #T_538a2_row10_col16, #T_538a2_row11_col16, #T_538a2_row12_col5, #T_538a2_row12_col8, #T_538a2_row13_col5 {
#   background-color: #2E924C;
#   font-weight: bold;
# }
# #T_538a2_row0_col11 {
#   background-color: #3da559;
#   color: #f1f1f1;
# }
# #T_538a2_row0_col12 {
#   background-color: #005e33;
#   color: #f1f1f1;
# }
# #T_538a2_row0_col13 {
#   background-color: #6fc174;
#   color: #000000;
# }
# #T_538a2_row0_col16, #T_538a2_row1_col5, #T_538a2_row2_col6, #T_538a2_row3_col5, #T_538a2_row3_col6, #T_538a2_row4_col5, #T_538a2_row5_col6, #T_538a2_row6_col6, #T_538a2_row8_col6, #T_538a2_row8_col16, #T_538a2_row10_col5, #T_538a2_row11_col5, #T_538a2_row11_col6, #T_538a2_row12_col6, #T_538a2_row12_col16, #T_538a2_row13_col6 {
#   background-color: #FFFFE5;
#   color: black;
#   opacity: 95%;
# }
# #T_538a2_row1_col6, #T_538a2_row4_col6, #T_538a2_row10_col6, #T_538a2_row10_col8, #T_538a2_row11_col8, #T_538a2_row13_col8, #T_538a2_row13_col16 {
#   background-color: red;
#   font-weight: bold;
# }
# #T_538a2_row1_col11, #T_538a2_row2_col11, #T_538a2_row4_col11, #T_538a2_row9_col11, #T_538a2_row11_col11 {
#   background-color: #e1f3a9;
#   color: #000000;
# }
# #T_538a2_row1_col12 {
#   background-color: #7fc97c;
#   color: #000000;
# }
# #T_538a2_row1_col13 {
#   background-color: #f8fcbe;
#   color: #000000;
# }
# #T_538a2_row2_col12 {
#   background-color: #0a703a;
#   color: #f1f1f1;
# }
# #T_538a2_row2_col13 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_538a2_row3_col11, #T_538a2_row3_col13, #T_538a2_row4_col12 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# #T_538a2_row3_col12 {
#   background-color: #8ed082;
#   color: #000000;
# }
# #T_538a2_row4_col13, #T_538a2_row8_col13 {
#   background-color: #74c477;
#   color: #000000;
# }
# #T_538a2_row5_col11, #T_538a2_row6_col11 {
#   background-color: #005c32;
#   color: #f1f1f1;
# }
# #T_538a2_row5_col12, #T_538a2_row5_col13, #T_538a2_row6_col12, #T_538a2_row6_col13, #T_538a2_row7_col11 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_538a2_row7_col12 {
#   background-color: #005a31;
#   color: #f1f1f1;
# }
# #T_538a2_row7_col13 {
#   background-color: #167a3f;
#   color: #f1f1f1;
# }
# #T_538a2_row8_col11 {
#   background-color: #c0e597;
#   color: #000000;
# }
# #T_538a2_row8_col12 {
#   background-color: #31974f;
#   color: #f1f1f1;
# }
# #T_538a2_row9_col12 {
#   background-color: #1e8041;
#   color: #f1f1f1;
# }
# #T_538a2_row9_col13 {
#   background-color: #40aa5c;
#   color: #f1f1f1;
# }
# #T_538a2_row10_col11 {
#   background-color: #fbfdcf;
#   color: #000000;
# }
# #T_538a2_row10_col12 {
#   background-color: #b5e092;
#   color: #000000;
# }
# #T_538a2_row10_col13 {
#   background-color: #4eb163;
#   color: #f1f1f1;
# }
# #T_538a2_row11_col12 {
#   background-color: #84cb7e;
#   color: #000000;
# }
# #T_538a2_row11_col13 {
#   background-color: #6dc073;
#   color: #000000;
# }
# #T_538a2_row12_col11 {
#   background-color: #d9f0a3;
#   color: #000000;
# }
# #T_538a2_row12_col12 {
#   background-color: #2b8e4a;
#   color: #f1f1f1;
# }
# #T_538a2_row12_col13 {
#   background-color: #7cc87b;
#   color: #000000;
# }
# #T_538a2_row13_col11 {
#   background-color: #daf0a4;
#   color: #000000;
# }
# #T_538a2_row13_col12 {
#   background-color: #1c7e40;
#   color: #f1f1f1;
# }
# #T_538a2_row13_col13 {
#   background-color: #77c679;
#   color: #000000;
# }
# </style>
# <table id="T_538a2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_538a2_level0_col0" class="col_heading level0 col0" >acao</th>
#       <th id="T_538a2_level0_col1" class="col_heading level0 col1" >Subsetor de Atuação</th>
#       <th id="T_538a2_level0_col2" class="col_heading level0 col2" >Valor atual</th>
#       <th id="T_538a2_level0_col3" class="col_heading level0 col3" >Dividend Yield</th>
#       <th id="T_538a2_level0_col4" class="col_heading level0 col4" >Valorização (12m) %</th>
#       <th id="T_538a2_level0_col5" class="col_heading level0 col5" >P/L</th>
#       <th id="T_538a2_level0_col6" class="col_heading level0 col6" >P/VP</th>
#       <th id="T_538a2_level0_col7" class="col_heading level0 col7" >EV/EBITDA</th>
#       <th id="T_538a2_level0_col8" class="col_heading level0 col8" >PEG Ratio</th>
#       <th id="T_538a2_level0_col9" class="col_heading level0 col9" >CAGR Receitas 5 anos %</th>
#       <th id="T_538a2_level0_col10" class="col_heading level0 col10" >CAGR Lucros 5 anos %</th>
#       <th id="T_538a2_level0_col11" class="col_heading level0 col11" >M. EBITDA %</th>
#       <th id="T_538a2_level0_col12" class="col_heading level0 col12" >ROE %</th>
#       <th id="T_538a2_level0_col13" class="col_heading level0 col13" >ROIC %</th>
#       <th id="T_538a2_level0_col14" class="col_heading level0 col14" >Dívida líquida</th>
#       <th id="T_538a2_level0_col15" class="col_heading level0 col15" >Dív. líquida/PL</th>
#       <th id="T_538a2_level0_col16" class="col_heading level0 col16" >Dív. líquida/EBITDA</th>
#       <th id="T_538a2_level0_col17" class="col_heading level0 col17" >Liq. corrente</th>
#       <th id="T_538a2_level0_col18" class="col_heading level0 col18" >link</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_538a2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_538a2_row0_col0" class="data row0 col0" >CSAN3</td>
#       <td id="T_538a2_row0_col1" class="data row0 col1" >Petróleo. Gás e Biocombustíveis</td>
#       <td id="T_538a2_row0_col2" class="data row0 col2" >17.25</td>
#       <td id="T_538a2_row0_col3" class="data row0 col3" >4.65</td>
#       <td id="T_538a2_row0_col4" class="data row0 col4" >-25.07%</td>
#       <td id="T_538a2_row0_col5" class="data row0 col5" >6.56</td>
#       <td id="T_538a2_row0_col6" class="data row0 col6" >2.07</td>
#       <td id="T_538a2_row0_col7" class="data row0 col7" >5.40</td>
#       <td id="T_538a2_row0_col8" class="data row0 col8" >0.07</td>
#       <td id="T_538a2_row0_col9" class="data row0 col9" >26.99%</td>
#       <td id="T_538a2_row0_col10" class="data row0 col10" >36.60%</td>
#       <td id="T_538a2_row0_col11" class="data row0 col11" >37.88%</td>
#       <td id="T_538a2_row0_col12" class="data row0 col12" >31.49%</td>
#       <td id="T_538a2_row0_col13" class="data row0 col13" >11.19%</td>
#       <td id="T_538a2_row0_col14" class="data row0 col14" >31266199000.00</td>
#       <td id="T_538a2_row0_col15" class="data row0 col15" >2.00</td>
#       <td id="T_538a2_row0_col16" class="data row0 col16" >2.65</td>
#       <td id="T_538a2_row0_col17" class="data row0 col17" >1.89</td>
#       <td id="T_538a2_row0_col18" class="data row0 col18" >https://statusinvest.com.br/acoes/CSAN3</td>
#     </tr>
#     <tr>
#       <th id="T_538a2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_538a2_row1_col0" class="data row1 col0" >DMMO3</td>
#       <td id="T_538a2_row1_col1" class="data row1 col1" >Petróleo. Gás e Biocombustíveis</td>
#       <td id="T_538a2_row1_col2" class="data row1 col2" >1.74</td>
#       <td id="T_538a2_row1_col3" class="data row1 col3" >0.00</td>
#       <td id="T_538a2_row1_col4" class="data row1 col4" >125.97%</td>
#       <td id="T_538a2_row1_col5" class="data row1 col5" >-39.86</td>
#       <td id="T_538a2_row1_col6" class="data row1 col6" >-1.76</td>
#       <td id="T_538a2_row1_col7" class="data row1 col7" >0.00</td>
#       <td id="T_538a2_row1_col8" class="data row1 col8" >0.38</td>
#       <td id="T_538a2_row1_col9" class="data row1 col9" >-1.34%</td>
#       <td id="T_538a2_row1_col10" class="data row1 col10" >0.00%</td>
#       <td id="T_538a2_row1_col11" class="data row1 col11" >0.00%</td>
#       <td id="T_538a2_row1_col12" class="data row1 col12" >-4.42%</td>
#       <td id="T_538a2_ro

# %% [markdown]
# <p> Esta é uma maneira que eu utilizo para visualizar e filtrar ações, podemos também realizar diversas outras analises com base neste conjunto de dados, como verificar as distribuições, tendências e comportamentos dos indicadores para este conjunto de ações </p>

# %% [markdown]
# Mas isto irei realizar futuramente, onde desenvolverei mais um projeto o qual terá como foco a aplicação de tecnicas de <b> data visualization </b> como a criação de diversos gráficos.

# %% [markdown]
# <h2 style='color:blue'> Espero que este conteúdo consiga lhe ajudar de alguma forma! </h2>
